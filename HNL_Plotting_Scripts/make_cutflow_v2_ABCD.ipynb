# %%
import sys
import importlib
import numpy as np
import pandas as pd
import uproot
import matplotlib.pyplot as plt
import sys
sys.path.insert(0,"../")

# %%
sys.path.insert(0,"../python/HNL_Plotting_HelperFunctions")
import MuonSystemReader
import Produce_Cutflow_v2
import analysis_helpers
import Processing_Helpers
# Out:
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /cvmfs/cms.cern.ch/el8_amd64_gcc12/external/py3-numpy/1.24.3-0831476b9e4ddf0b4b9eb1f4c971c0d1/lib/python3.9/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
# ...

# %%
#HNL_2GeV_10ctau_path = "root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/signal_displacedHNL/HNL_tau_mN_2_ctau_1000/normalized/HNL_tau_mN_2_ctau_1000.root"
#HNL_2GeV_10ctau_path = "root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/signal_tau_PNetUpdate/HNL_tau_mN_2_ctau_1000/normalized/HNL_tau_mN_2_ctau_1000.root"
#HNL_2GeV_10ctau_path = "root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/analyzer_update_111825/HNL_tau_mN_2_ctau_1000/normalized/HNL_tau_mN_2_ctau_1000.root"
HNL_2GeV_10ctau_path = "root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/analyzer_update_012026/HNL_tau_mN_2_ctau_1000/normalized/HNL_tau_mN_2_ctau_1000_109080pb_weighted.root"
signal_events  = MuonSystemReader.loadTree_nanoFactory(HNL_2GeV_10ctau_path)
signal_events
# Out:
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/coffea/nanoevents/factory.py:317: RuntimeWarning: You have set steps_per_file to 4, this should only be used for a
#                 small number of inputs (e.g. for early-stage/exploratory analysis) since it does not
#                 inform dask of each chunk lengths at creation time, which can cause unexpected
#                 slowdowns at scale. If you would like to process larger datasets please specify steps
#                 using the appropriate uproot "files" specification:
#                     https://github.com/scikit-hep/uproot5/blob/v5.1.2/src/uproot/_dask.py#L109-L132.
#
#   warnings.warn(
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/dask_awkward/lib/structure.py:911: UserWarning: Please ensure that dask.awkward<nCscRechitClusters, npartitions=4>
#         is partitionwise-compatible with dask.awkward<getitem, npartitions=4>
#         (e.g. counts comes from a dak.num(array, axis=1)),
# ...

# %%
data_path_base = "root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/2024_Data_tauh_analyzer_update_012026/"
data_events_list = Processing_Helpers.make_data_list(data_path_base, 'tau')
data_events  = MuonSystemReader.loadTree_nanoFactory(data_events_list)
# Out:
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/dask_awkward/lib/structure.py:911: UserWarning: Please ensure that dask.awkward<nCscRechitClusters, npartitions=80>
#         is partitionwise-compatible with dask.awkward<getitem, npartitions=80>
#         (e.g. counts comes from a dak.num(array, axis=1)),
#         otherwise this unflatten operation will fail when computed!
#   warnings.warn(

# %%
#importlib.reload(MuonSystemReader)
importlib.reload(Produce_Cutflow_v2)
#importlib.reload(analysis_helpers)
# Out:
# <module 'Produce_Cutflow_v2' from '/uscms_data/d3/amalbert/el9_work/CMSSW_14_1_0_pre4/src/run3_llp_analyzer/HNL_Plotting_Scripts/../python/HNL_Plotting_HelperFunctions/Produce_Cutflow_v2.py'>

# %%
cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='tau_SR/cuts_sensitivity_tau_DNN.yaml', isMC=True, ABCD=True, blind=False, flavor="Tau", signal_xsec=1, reweight_ctau=100)
cutflow_signal
# Out:
# about to compute
# entering ABCD code
#                      Cut Name  Number of Weighted Events
# 0                Pass Trigger                 254.062078  \
# 1                  MET>30 GeV                 201.501530
# 2                 nLeptons==0                 153.928961
# 3     -5ns<clusterTime<12.5ns                 153.928961
# 4             no hits ME11/12                 153.857489
# 5            MuonVetoPt<30GeV                 151.696140
# 6            JetVetoPt<10 GeV                 149.237001
# 7    |dPhi(cluster, MET)|<1.5                 137.004894
# 8               exactly 1 tau                  69.356438
# 9                 tauPt>20GeV                  63.083579
# 10           tau pass tightID                  18.854789
# 11  |DeltaEta(cluster,tau)|<2                  18.514303
# 12                DNN>0.99975                   1.672623
#
#     Number of Unweighted Events  Cut Efficiency  Cumulative Efficiency
# ...

# %%
ABCD_signal
# Out:
#                              Bin                                        Counts
# 0    bin A (low NHits, low dPhi)  0.003865418605464026 +- 0.062172490745216455
# 1   bin B (low NHits, high dPhi)                                    0.0 +- 0.0
# 2   bin C (high NHits, low dPhi)      1.3904789895575211 +- 1.1791857315781602
# 3  bin D (high NHits, high dPhi)      0.2782790192605053 +- 0.5275215817959539

# %%
cutflow_data, ABCD_data = Produce_Cutflow_v2.makeCutflow(data_events, cfg_file='cuts_sensitivity_tau_DNN.yaml', isMC=False, ABCD=True)
cutflow_data
# Out:
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34771 instead
#   warnings.warn(
#                      Cut Name Number of Weighted Events
# 0                Pass Trigger                11901101.0  \
# 1                  MET>30 GeV                 6405035.0
# 2                 nLeptons==0                 3606340.0
# 3     -5ns<clusterTime<12.5ns                 3136484.0
# 4             no hits ME11/12                 3104301.0
# 5            MuonVetoPt<30GeV                 2960839.0
# 6            JetVetoPt<10 GeV                 1888171.0
# 7                 DNN>0.99975                   24161.0
# 8    |dPhi(cluster, MET)|<1.5                   11677.0
# 9               exactly 1 tau                   10676.0
# 10                tauPt>20GeV                    9124.0
# ...

# %%
ABCD_data
# Out:
#                                       Bin
# 0             bin A (low NHits, low dPhi)  \
# 1            bin B (low NHits, high dPhi)
# 2            bin C (high NHits, low dPhi)
# 3  bin D expected (high NHits, high dPhi)
#
#                                    Counts
# 0               61.0 +- 7.810249675906654
# 1               58.0 +- 7.615773105863909
# 2              10.0 +- 3.1622776601683795
# 3  9.508196721311474 +- 3.475825605286635

# %%
outDataCardsDir = '/uscms/home/amalbert/nobackup/el9_work/CMSSW_14_1_0_pre4/src/HiggsAnalysis/CombinedLimit/Datacards/first_ABCD_counts/'
signal_name = 'HNL_tau_noLepton'
mass = 2
sig_unc = {'dummy':[[0.2,0.2,0.2,0.2]]}
sig_unc_name = ['dummy']
signal_region='A'
prefix='bin'


ctaus = [10, 25, 50, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000]
for ctau in ctaus:
    print(f"running for ctau {ctau}")
    cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='cuts_sensitivity_tau_DNN.yaml', reweight_ctau=ctau, isMC=True, ABCD=True, blind=False)
    #print(ABCD_signal)
    #ctau = 1000

    list_signal = [float(counts[:counts.find("+-")]) for counts in ABCD_signal['Counts']]
    list_data = [float(counts[:counts.find("+-")]) for counts in ABCD_data['Counts']]

    signal_rate = {f'{signal_name}':[list_signal[3],list_signal[1],list_signal[0], list_signal[2]]}
    norm = 1/(signal_rate[f'{signal_name}'][0])
    bkg_rate = [list_data[3],list_data[1],list_data[0], list_data[2]]
    observation = bkg_rate
    #print(signal_rate)
    #print(norm)
    #analysis_helpers.make_datacard_2tag(outDataCardsDir,signal_name,  signal_rate, norm, bkg_rate, observation, sig_unc, sig_unc_name, signal_region, prefix, mass, ctau)
# Out:
# running for ctau 10
# about to com0pute weights
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 13
#      11 for ctau in ctaus:
#      12     print(f"running for ctau {ctau}")
# ---> 13     cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='cuts_sensitivity_tau_DNN.yaml', reweight_ctau=ctau, isMC=True, ABCD=True, blind=False)
#      14     #print(ABCD_signal)
#      15     #ctau = 1000
#      17     list_signal = [float(counts[:counts.find("+-")]) for counts in ABCD_signal['Counts']]
#
# File /uscms_data/d3/amalbert/el9_work/CMSSW_14_1_0_pre4/src/run3_llp_analyzer/HNL_Plotting_Scripts/../python/HNL_Plotting_HelperFunctions/Produce_Cutflow_v2.py:90, in makeCutflow(events, cfg_file, isMC, noGenCuts, Run, sample_ctau, reweight_ctau, ABCD, sizeCut, dPhiCut, dEtaCut, blind, flavor, signal_xsec, genEvents, dEta)
# ...

# %% [markdown]
# ### Cutflows with HT

# %%
cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='tau_SR/cuts_sensitivity_tau_DNN_HT.yaml', isMC=True, ABCD=True, blind=False, flavor="Tau", signal_xsec=1)
cutflow_signal
# Out:
# about to compute
# entering ABCD code
#                            Cut Name  Number of Weighted Events
# 0                      Pass Trigger                 144.148119  \
# 1                        MET>30 GeV                 103.397624
# 2                       nLeptons==0                  78.786825
# 3           -5ns<clusterTime<12.5ns                  78.786825
# 4                   no hits ME11/12                  78.698673
# 5                  MuonVetoPt<30GeV                  77.448279
# 6                  JetVetoPt<10 GeV                  75.580049
# 7          |dPhi(cluster, MET)|<1.5                  65.761775
# 8                     exactly 1 tau                  35.633729
# 9                       tauPt>20GeV                  32.245501
# 10                 tau pass tightID                  11.141129
# 11        |DeltaEta(cluster,tau)|<2                  10.588321
# 12                      DNN>0.99975                   0.872909
# ...

# %%
ABCD_signal
# Out:
#                              Bin                                     Counts
# 0    bin A (low NHits, low dPhi)   0.1641649703752359 +- 0.4051727660828599
# 1   bin B (low NHits, high dPhi)                                 0.0 +- 0.0
# 2   bin C (high NHits, low dPhi)  0.09643778925714093 +- 0.3105443434634431
# 3  bin D (high NHits, high dPhi)  0.23353537475718536 +- 0.4832549790298961

# %%
cutflow_data, ABCD_data = Produce_Cutflow_v2.makeCutflow(data_events, cfg_file='tau_SR/cuts_sensitivity_tau_DNN_HT.yaml', isMC=False, ABCD=True)
cutflow_data
# Out:
# about to compute
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-10062' coro=<Client._gather.<locals>.wait() done, defined at /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/client.py:2396> exception=AllExit()>
# Traceback (most recent call last):
#   File "/uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/client.py", line 2405, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-10063' coro=<Client._gather.<locals>.wait() done, defined at /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/client.py:2396> exception=AllExit()>
# Traceback (most recent call last):
#   File "/uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/client.py", line 2405, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# ...

# %%
ABCD_data
# Out:
#                                       Bin
# 0             bin A (low NHits, low dPhi)  \
# 1            bin B (low NHits, high dPhi)
# 2            bin C (high NHits, low dPhi)
# 3  bin D expected (high NHits, high dPhi)
#
#                                     Counts
# 0                19.0 +- 4.358898943540674
# 1                15.0 +- 3.872983346207417
# 2                3.0 +- 1.7320508075688772
# 3  2.3684210526315788 +- 1.593423940514938

# %%
outDataCardsDir = '/uscms/home/amalbert/nobackup/el9_work/CMSSW_14_1_0_pre4/src/HiggsAnalysis/CombinedLimit/Datacards/first_ABCD_counts/'
signal_name = 'HNL_tau_HTCut'
mass = 2
sig_unc = {'dummy':[[0.2,0.2,0.2,0.2]]}
sig_unc_name = ['dummy']
signal_region='A'
prefix='bin'


ctaus = [10, 25, 50, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000]
for ctau in ctaus:
    print(f"running for ctau {ctau}")
    cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='tau_SR/cuts_sensitivity_tau_DNN_HT.yaml', reweight_ctau=ctau, isMC=True, ABCD=True, blind=False)
    #print(ABCD_signal)
    #ctau = 1000

    list_signal = [float(counts[:counts.find("+-")]) for counts in ABCD_signal['Counts']]
    list_data = [float(counts[:counts.find("+-")]) for counts in ABCD_data['Counts']]

    signal_rate = {f'{signal_name}':[list_signal[3],list_signal[1],list_signal[0], list_signal[2]]}
    norm = 1/(signal_rate[f'{signal_name}'][0])
    bkg_rate = [list_data[3],list_data[1],list_data[0], list_data[2]]
    observation = bkg_rate
    #print(signal_rate)
    #print(norm)
    analysis_helpers.make_datacard_2tag(outDataCardsDir,signal_name,  signal_rate, norm, bkg_rate, observation, sig_unc, sig_unc_name, signal_region, prefix, mass, ctau)
# Out:
# running for ctau 10
# about to compute
# entering ABCD code
#
# running for ctau 25
# about to compute
# entering ABCD code
#
# running for ctau 50
# about to compute
# entering ABCD code
#
# running for ctau 100
# about to compute
# entering ABCD code
#
# running for ctau 250
# about to compute
# entering ABCD code
#
# running for ctau 500
# about to compute
# entering ABCD code
#
# running for ctau 750
# about to compute
# entering ABCD code
#
# running for ctau 1000
# about to compute
# entering ABCD code
#
# running for ctau 2500
# about to compute
# entering ABCD code
#
# running for ctau 5000
# about to compute
# entering ABCD code
#
# running for ctau 7500
# about to compute
# entering ABCD code
#
# running for ctau 10000
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# ...

# %% [markdown]
# ### HT but no MET

# %%
cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='tau_SR/cuts_sensitivity_tau_DNN_HT_noMET.yaml', isMC=True, ABCD=True, blind=False, flavor="Tau", signal_xsec=1)
cutflow_signal
# Out:
# about to compute
# entering ABCD code
#                            Cut Name  Number of Weighted Events
# 0                      Pass Trigger                 144.148119  \
# 1                       nLeptons==0                 107.516670
# 2           -5ns<clusterTime<12.5ns                 107.516670
# 3                   no hits ME11/12                 107.428517
# 4                  MuonVetoPt<30GeV                 105.175898
# 5                  JetVetoPt<10 GeV                 102.721064
# 6          |dPhi(cluster, MET)|<1.5                  83.968762
# 7                     exactly 1 tau                  43.683658
# 8                       tauPt>20GeV                  39.710366
# 9                  tau pass tightID                  14.354827
# 10        |DeltaEta(cluster,tau)|<2                  13.358722
# 11                      DNN>0.99975                   1.102334
# 12  HTSoftJetsEtaLargerThan3.139<20                   0.723563
#
# ...

# %%
ABCD_signal
# Out:
#                              Bin                                     Counts
# 0    bin A (low NHits, low dPhi)   0.1641649703752359 +- 0.4051727660828599
# 1   bin B (low NHits, high dPhi)   0.09313447133757426 +- 0.305179408442926
# 2   bin C (high NHits, low dPhi)  0.09643778925714093 +- 0.3105443434634431
# 3  bin D (high NHits, high dPhi)   0.3698258306203534 +- 0.6081330698295838

# %%
cutflow_data, ABCD_data = Produce_Cutflow_v2.makeCutflow(data_events, cfg_file='tau_SR/cuts_sensitivity_tau_DNN_HT_noMET.yaml', isMC=False, ABCD=True)
cutflow_data
# Out:
# about to compute
# entering ABCD code
#                            Cut Name Number of Weighted Events
# 0                      Pass Trigger                 7462926.0  \
# 1                       nLeptons==0                 6150794.0
# 2           -5ns<clusterTime<12.5ns                 5247978.0
# 3                   no hits ME11/12                 5204699.0
# 4                  MuonVetoPt<30GeV                 4989750.0
# 5                  JetVetoPt<10 GeV                 3229994.0
# 6          |dPhi(cluster, MET)|<1.5                 1618100.0
# 7                     exactly 1 tau                 1482366.0
# 8                       tauPt>20GeV                 1274486.0
# 9                  tau pass tightID                   33958.0
# 10        |DeltaEta(cluster,tau)|<2                   21721.0
# 11                      DNN>0.99975                     255.0
# 12  HTSoftJetsEtaLargerThan3.139<20                         X
#
# ...

# %%
ABCD_data
# Out:
#                                       Bin
# 0             bin A (low NHits, low dPhi)  \
# 1            bin B (low NHits, high dPhi)
# 2            bin C (high NHits, low dPhi)
# 3  bin D expected (high NHits, high dPhi)
#
#                                     Counts
# 0                53.0 +- 7.280109889280518
# 1                39.0 +- 6.244997998398398
# 2               10.0 +- 3.1622776601683795
# 3  7.3584905660377355 +- 2.797281096182962

# %%
outDataCardsDir = '/uscms/home/amalbert/nobackup/el9_work/CMSSW_14_1_0_pre4/src/HiggsAnalysis/CombinedLimit/Datacards/first_ABCD_counts/'
signal_name = 'HNL_tau_HTCut_noMET'
mass = 2
sig_unc = {'dummy':[[0.2,0.2,0.2,0.2]]}
sig_unc_name = ['dummy']
signal_region='A'
prefix='bin'


ctaus = [10, 25, 50, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000]
for ctau in ctaus:
    print(f"running for ctau {ctau}")
    cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='tau_SR/cuts_sensitivity_tau_DNN_HT_noMET.yaml', reweight_ctau=ctau, isMC=True, ABCD=True, blind=False)
    #print(ABCD_signal)
    #ctau = 1000

    list_signal = [float(counts[:counts.find("+-")]) for counts in ABCD_signal['Counts']]
    list_data = [float(counts[:counts.find("+-")]) for counts in ABCD_data['Counts']]

    signal_rate = {f'{signal_name}':[list_signal[3],list_signal[1],list_signal[0], list_signal[2]]}
    norm = 1/(signal_rate[f'{signal_name}'][0])
    bkg_rate = [list_data[3],list_data[1],list_data[0], list_data[2]]
    observation = bkg_rate
    #print(signal_rate)
    #print(norm)
    analysis_helpers.make_datacard_2tag(outDataCardsDir,signal_name,  signal_rate, norm, bkg_rate, observation, sig_unc, sig_unc_name, signal_region, prefix, mass, ctau)
# Out:
# running for ctau 10
# about to compute
# entering ABCD code
#
# running for ctau 25
# about to compute
# entering ABCD code
#
# running for ctau 50
# about to compute
# entering ABCD code
#
# running for ctau 100
# about to compute
# entering ABCD code
#
# running for ctau 250
# about to compute
# entering ABCD code
#
# running for ctau 500
# about to compute
# entering ABCD code
#
# running for ctau 750
# about to compute
# entering ABCD code
#
# running for ctau 1000
# about to compute
# entering ABCD code
#
# running for ctau 2500
# about to compute
# entering ABCD code
#
# running for ctau 5000
# about to compute
# entering ABCD code
#
# running for ctau 7500
# about to compute
# entering ABCD code
#
# running for ctau 10000
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# ...

# %% [markdown]
# ### Check sensitvitiy with station veto

# %%
cutflow_signal_stationveto,ABCD_signal_stationveto = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='cuts_sensitivity_tau_stationveto.yaml', isMC=True, ABCD=True, blind=False)
cutflow_signal_stationveto
# Out:
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 32805 instead
#   warnings.warn(
#                      Cut Name  Number of Weighted Events
# 0                Pass Trigger                 155.463703  \
# 1                  MET>30 GeV                 109.935047
# 2                 nLeptons==0                  84.505627
# 3     -5ns<clusterTime<12.5ns                  84.505627
# 4      no hits Station 1 or 2                  42.641473
# 5                NStation10>1                  17.323098
# 6            MuonVetoPt<30GeV                  16.878916
# 7            JetVetoPt<10 GeV                  16.545780
# 8    |dPhi(cluster, MET)|<1.5                  14.546961
# 9               exactly 1 tau                   7.995276
# 10                tauPt>20GeV                   7.551094
# ...

# %%
ABCD_signal_stationveto
# Out:
#                              Bin                                    Counts
# 0    bin A (low NHits, low dPhi)                                0.0 +- 0.0
# 1   bin B (low NHits, high dPhi)                                0.0 +- 0.0
# 2   bin C (high NHits, low dPhi)  0.9994095208958242 +- 0.9997047168518434
# 3  bin D (high NHits, high dPhi)  2.3319555487569232 +- 1.5270741791926556

# %%
cutflow_data_stationveto, ABCD_data_stationveto = Produce_Cutflow_v2.makeCutflow(data_events, cfg_file='cuts_sensitivity_tau_stationveto.yaml', isMC=False, ABCD=True)
cutflow_data_stationveto
# Out:
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35397 instead
#   warnings.warn(
#                      Cut Name Number of Weighted Events
# 0                Pass Trigger                11901101.0  \
# 1                  MET>30 GeV                 6405035.0
# 2                 nLeptons==0                 3606340.0
# 3     -5ns<clusterTime<12.5ns                 3136484.0
# 4      no hits Station 1 or 2                  694537.0
# 5                NStation10>1                   50526.0
# 6            MuonVetoPt<30GeV                   46398.0
# 7            JetVetoPt<10 GeV                   21730.0
# 8    |dPhi(cluster, MET)|<1.5                   12305.0
# 9               exactly 1 tau                   11240.0
# 10                tauPt>20GeV                    9695.0
# ...

# %%
ABCD_data_stationveto
# Out:
#                                       Bin
# 0             bin A (low NHits, low dPhi)  \
# 1            bin B (low NHits, high dPhi)
# 2            bin C (high NHits, low dPhi)
# 3  bin D expected (high NHits, high dPhi)
#
#                                      Counts
# 0                               25.0 +- 5.0
# 1                 28.0 +- 5.291502622129181
# 2                 34.0 +- 5.830951894845301
# 3  38.080000000000005 +- 12.346734629042617

# %%
outDataCardsDir = '/uscms/home/amalbert/nobackup/el9_work/CMSSW_14_1_0_pre4/src/HiggsAnalysis/CombinedLimit/Datacards/first_ABCD_counts/'
signal_name = 'HNL_tau_noLepton_stationveto'
mass = 2
sig_unc = {'dummy':[[0.2,0.2,0.2,0.2]]}
sig_unc_name = ['dummy']
signal_region='A'
prefix='bin'


ctaus = [10, 25, 50, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000]
for ctau in ctaus:
    print(f"running for ctau {ctau}")
    cutflow_signal_stationveto,ABCD_signal_stationveto = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='cuts_sensitivity_tau_stationveto.yaml', reweight_ctau=ctau, isMC=True, ABCD=True, blind=False)
    #print(ABCD_signal)
    #ctau = 1000

    list_signal = [float(counts[:counts.find("+-")]) for counts in ABCD_signal_stationveto['Counts']]
    list_data = [float(counts[:counts.find("+-")]) for counts in ABCD_data_stationveto['Counts']]

    signal_rate = {f'{signal_name}':[list_signal[3],list_signal[1],list_signal[0], list_signal[2]]}
    norm = 1/(signal_rate[f'{signal_name}'][0])
    bkg_rate = [list_data[3],list_data[1],list_data[0], list_data[2]]
    observation = bkg_rate
    #print(signal_rate)
    #print(norm)
    analysis_helpers.make_datacard_2tag(outDataCardsDir,signal_name,  signal_rate, norm, bkg_rate, observation, sig_unc, sig_unc_name, signal_region, prefix, mass, ctau)
# Out:
# running for ctau 10
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40873 instead
#   warnings.warn(
# running for ctau 25
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 33527 instead
#   warnings.warn(
# running for ctau 50
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46547 instead
#   warnings.warn(
# running for ctau 100
# about to compute
# entering ABCD code
# ...

# %% [markdown]
# ### Check sensitvitiy with station veto, no NStation10>1 selection

# %%
cutflow_signal_stationveto_noNStation10,ABCD_signal_stationveto_noNStation10 = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='cuts_sensitivity_tau_stationveto_noNStation10.yaml', isMC=True, ABCD=True, blind=False)
cutflow_signal_stationveto_noNStation10
# Out:
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43251 instead
#   warnings.warn(
#                      Cut Name  Number of Weighted Events
# 0                Pass Trigger                 155.463703  \
# 1                  MET>30 GeV                 109.935047
# 2                 nLeptons==0                  84.505627
# 3     -5ns<clusterTime<12.5ns                  84.505627
# 4      no hits Station 1 or 2                  42.641473
# 5            MuonVetoPt<30GeV                  42.197291
# 6            JetVetoPt<10 GeV                  40.864745
# 7    |dPhi(cluster, MET)|<1.5                  36.200834
# 8               exactly 1 tau                  19.988190
# 9                 tauPt>20GeV                  18.544599
# 10           tau pass tightID                   6.995867
# ...

# %%
ABCD_signal_stationveto_noNStation10
# Out:
#                              Bin                                     Counts
# 0    bin A (low NHits, low dPhi)  0.33313650696527475 +- 0.5771797873845503
# 1   bin B (low NHits, high dPhi)   1.1104550232175825 +- 1.0537812976218464
# 2   bin C (high NHits, low dPhi)    1.776728037148132 +- 1.3329396224691243
# 3  bin D (high NHits, high dPhi)   3.3313650696527475 +- 1.8252027475468986

# %%
cutflow_data_stationveto_noNStation10, ABCD_data_stationveto_noNStation10 = Produce_Cutflow_v2.makeCutflow(data_events, cfg_file='cuts_sensitivity_tau_stationveto_noNStation10.yaml', isMC=False, ABCD=True)
cutflow_data_stationveto_noNStation10
# Out:
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 42681 instead
#   warnings.warn(
#                      Cut Name Number of Weighted Events
# 0                Pass Trigger                11901101.0  \
# 1                  MET>30 GeV                 6405035.0
# 2                 nLeptons==0                 3606340.0
# 3     -5ns<clusterTime<12.5ns                 3136484.0
# 4      no hits Station 1 or 2                  694537.0
# 5            MuonVetoPt<30GeV                  687712.0
# 6            JetVetoPt<10 GeV                  603424.0
# 7    |dPhi(cluster, MET)|<1.5                  294546.0
# 8               exactly 1 tau                  269461.0
# 9                 tauPt>20GeV                  231716.0
# 10           tau pass tightID                    5958.0
# ...

# %%
ABCD_data_stationveto_noNStation10
# Out:
#                                       Bin
# 0             bin A (low NHits, low dPhi)  \
# 1            bin B (low NHits, high dPhi)
# 2            bin C (high NHits, low dPhi)
# 3  bin D expected (high NHits, high dPhi)
#
#                                      Counts
# 0               1396.0 +- 37.36308338453881
# 1               1472.0 +- 38.36665218650175
# 2               379.0 +- 19.467922333931785
# 3  399.63323782234954 +- 25.382854240314657

# %%
outDataCardsDir = '/uscms/home/amalbert/nobackup/el9_work/CMSSW_14_1_0_pre4/src/HiggsAnalysis/CombinedLimit/Datacards/first_ABCD_counts/'
signal_name = 'HNL_tau_noLepton_stationveto_noNStation10'
mass = 2
sig_unc = {'dummy':[[0.2,0.2,0.2,0.2]]}
sig_unc_name = ['dummy']
signal_region='A'
prefix='bin'


ctaus = [10, 25, 50, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000]
for ctau in ctaus:
    print(f"running for ctau {ctau}")
    cutflow_signal_stationveto_noNStation10,ABCD_signal_stationveto_noNStation10 = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='cuts_sensitivity_tau_stationveto_noNStation10.yaml', reweight_ctau=ctau, isMC=True, ABCD=True, blind=False)
    #print(ABCD_signal)
    #ctau = 1000

    list_signal = [float(counts[:counts.find("+-")]) for counts in ABCD_signal_stationveto_noNStation10['Counts']]
    list_data = [float(counts[:counts.find("+-")]) for counts in ABCD_data_stationveto_noNStation10['Counts']]

    signal_rate = {f'{signal_name}':[list_signal[3],list_signal[1],list_signal[0], list_signal[2]]}
    norm = 1/(signal_rate[f'{signal_name}'][0])
    bkg_rate = [list_data[3],list_data[1],list_data[0], list_data[2]]
    observation = bkg_rate
    #print(signal_rate)
    #print(norm)
    analysis_helpers.make_datacard_2tag(outDataCardsDir,signal_name,  signal_rate, norm, bkg_rate, observation, sig_unc, sig_unc_name, signal_region, prefix, mass, ctau)
# Out:
# running for ctau 10
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37565 instead
#   warnings.warn(
# running for ctau 25
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39495 instead
#   warnings.warn(
# running for ctau 50
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 32895 instead
#   warnings.warn(
# running for ctau 100
# about to compute
# entering ABCD code
# ...

# %% [markdown]
# ### with dEta instead of dPhi

# %%
importlib.reload(Produce_Cutflow_v2)
# Out:
# <module 'Produce_Cutflow_v2' from '/uscms_data/d3/amalbert/el9_work/CMSSW_14_1_0_pre4/src/run3_llp_analyzer/HNL_Plotting_Scripts/../python/HNL_Plotting_HelperFunctions/Produce_Cutflow_v2.py'>

# %%
cutflow_signal,ABCD_signal = Produce_Cutflow_v2.makeCutflow(signal_events, cfg_file='cuts_sensitivity_tau_DNN_fordEta.yaml', isMC=True, ABCD=True, blind=False, dEta=True)
cutflow_signal
# Out:
# 1
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39859 instead
#   warnings.warn(
#                              Cut Name  Number of Weighted Events
# 0                        Pass Trigger                 143.137652  \
# 1                          MET>30 GeV                 101.384544
# 2                         nLeptons==0                  77.509761
# 3             -5ns<clusterTime<12.5ns                  77.509761
# 4                     no hits ME11/12                  77.398715
# 5                    MuonVetoPt<30GeV                  75.621987
# 6                    JetVetoPt<10 GeV                  73.845259
# 7                         DNN>0.99975                   7.884231
# 8            |dPhi(cluster, MET)|<1.5                   6.884821
# ...

# %%
ABCD_signal
# Out:
#                              Bin                                     Counts
# 0    bin A (low NHits, low dEta)                                 0.0 +- 0.0
# 1   bin B (low NHits, high dEta)  0.11104550232175825 +- 0.3332349056172811
# 2   bin C (high NHits, low dEta)                                 0.0 +- 0.0
# 3  bin D (high NHits, high dEta)  0.33313650696527475 +- 0.5771797873845503

# %%
cutflow_data, ABCD_data = Produce_Cutflow_v2.makeCutflow(data_events, cfg_file='cuts_sensitivity_tau_DNN_fordEta.yaml', isMC=False, ABCD=True, dEta=True)
cutflow_data
# Out:
# 1
# about to compute
# entering ABCD code
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41905 instead
#   warnings.warn(
#                              Cut Name Number of Weighted Events
# 0                        Pass Trigger                 7469240.0  \
# 1                          MET>30 GeV                 3912428.0
# 2                         nLeptons==0                 3175732.0
# 3             -5ns<clusterTime<12.5ns                 2727893.0
# 4                     no hits ME11/12                 2704754.0
# 5                    MuonVetoPt<30GeV                 2582869.0
# 6                    JetVetoPt<10 GeV                 1657661.0
# 7                         DNN>0.99975                   21241.0
# 8            |dPhi(cluster, MET)|<1.5                   10277.0
# ...

# %%
ABCD_data
# Out:
#                                       Bin
# 0             bin A (low NHits, low dEta)  \
# 1            bin B (low NHits, high dEta)
# 2            bin C (high NHits, low dEta)
# 3  bin D expected (high NHits, high dEta)
#
#                                     Counts
# 0                59.0 +- 7.681145747868608
# 1                48.0 +- 6.928203230275509
# 2                8.0 +- 2.8284271247461903
# 3  9.833333333333334 +- 3.9673873061546487

# %%
# TODO: make datacards for dEta study too
