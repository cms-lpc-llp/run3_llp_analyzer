# %%
import warnings
warnings.filterwarnings("ignore", module="coffea")
warnings.filterwarnings("ignore",
                        message="The value of the smallest subnormal",
                        module="numpy.core.getlimits")


import sys
import importlib
import numpy as np
import pandas as pd




import uproot
import matplotlib.pyplot as plt
import sys
sys.path.insert(0,"../")
import mplhep as hep

# %%
sys.path.insert(0,"../python/HNL_Plotting_HelperFunctions")
import MuonSystemReader
import HNL_Processor
import HNL_Processor_v2_mu
import Processing_Helpers
import analysis_helpers
# Out:
# Welcome to JupyROOT 6.30/07

# %%
data_label = "Data"
tau_mu_label = "HNL mN_{#tau}=2GeV ctau=1cm"
mu_label = "HNL mN_{#mu}=2GeV ctau=1cm"
ZMuMu_label = "Z #rightarrow #mu#mu MC"

# %%
sensitivity_hists = ["CSC_Cluster_Size", "CSC_Cluster_Eta", "CSC_Cluster_Phi", "CSC_Cluster_JetVetoPt", "CSC_Cluster_MuonVetoPt", "CSC_Cluster_PuppiMetDPhi",
                    "CSC_Cluster_DNNScore", "CSC_Cluster_DNNScore_TightRange", "CSC_Cluster_Muon_DeltaEta", "CSC_Cluster_Muon_DeltaPhi", "CSC_Cluster_Muon_DeltaR", "muon_pt", "muon_eta", "muon_phi", "PUPPI_MET",
                    "CSC_Cluster_Time", "CSC_Cluster_TimeSpread"]
#sensitivity_hists = ["CSC_Cluster_Eta", "CSC_Cluster_JetVetoPt", "CSC_Cluster_MuonVetoPt", "CSC_Cluster_PuppiMetDPhi"]                   
#sensitivity_hists = ["CSC_Cluster_JetVetoPt"]
#sensitivity_hists = ["CSC_Cluster_DNNScore", "CSC_Cluster_Tau_DeltaEta", "CSC_Cluster_Tau_DeltaEta"]
#sensitivity_hists = ["CSC_Cluster_Tau_DeltaEta", "CSC_Cluster_Tau_DeltaPhi"]
#sensitivity_hists = ["PUPPI_MET", "Num_Taus"]
#sensitivity_hists = ["CSC_Cluster_Muon_DeltaR"]
#sensitivity_hists = ["CSC_Cluster_Phi"]

# %%
HNL_2GeV_10ctau_path = "root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/analyzer_update_111825/HNL_mu_mN_2_ctau_1000/normalized/HNL_mu_mN_2_ctau_1000.root"
signal_events  = MuonSystemReader.loadTree_nanoFactory(HNL_2GeV_10ctau_path)
# Out:
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/dask_awkward/lib/structure.py:911: UserWarning: Please ensure that dask.awkward<nCscRechitClusters, npartitions=4>
#         is partitionwise-compatible with dask.awkward<getitem, npartitions=4>
#         (e.g. counts comes from a dak.num(array, axis=1)),
#         otherwise this unflatten operation will fail when computed!
#   warnings.warn(

# %%
HNL_2GeV_10ctau_path = "root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/analyzer_update_111825/HNL_tau_mN_2_ctau_1000/normalized/HNL_tau_mN_2_ctau_1000.root"
signal_events_tau  = MuonSystemReader.loadTree_nanoFactory(HNL_2GeV_10ctau_path)

# %%
ZMuMu_events = MuonSystemReader.loadTree_nanoFactory("root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/ZMuMu_MC/DYto2Mu_Bin-MLL-50to120_TuneCP5_13p6TeV_powheg-pythia8/normalized/DYto2Mu_Bin-MLL-50to120_TuneCP5_13p6TeV_powheg-pythia8.root")

# %%
importlib.reload(MuonSystemReader)
importlib.reload(HNL_Processor_v2_mu)
#importlib.reload(Processing_Helpers)
# Out:
# <module 'HNL_Processor_v2_mu' from '/uscms_data/d3/amalbert/el9_work/CMSSW_14_1_0_pre4/src/run3_llp_analyzer/HNL_Plotting_Scripts/../python/HNL_Plotting_HelperFunctions/HNL_Processor_v2_mu.py'>

# %%
output_data = Processing_Helpers.processData_v2_mu("root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/2024_Data_mu/", sensitivity_hists)
# Out:
# root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/2024_Data_mu/Muon0-Run2024B-PromptReco-v1/normalized/Muon0-Run2024B-PromptReco-v1_goodLumi.root
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39823 instead
#   warnings.warn(
# about to compute
# root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/2024_Data_mu/Muon0-Run2024C-PromptReco-v1/normalized/Muon0-Run2024C-PromptReco-v1_goodLumi.root
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45079 instead
#   warnings.warn(
# about to compute
# ...

# %%
#sensitivity_hists = ["CSC_Cluster_Tau_DeltaEta", "CSC_Cluster_Tau_DeltaPhi"]
processor = HNL_Processor_v2_mu.HNL_Processor_v2_mu(isMC=True, applyGenInfo=False)
output = processor.process(signal_events, hists_to_process = sensitivity_hists)
# Out:
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37149 instead
#   warnings.warn(
# about to compute
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# ...

# %%
#sensitivity_hists = ["CSC_Cluster_Tau_DeltaEta", "CSC_Cluster_Tau_DeltaPhi"]
processor = HNL_Processor_v2_mu.HNL_Processor_v2_mu(isMC=True, applyGenInfo=False, fromTau=True)
output_tau = processor.process(signal_events_tau, hists_to_process = sensitivity_hists)
# Out:
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44685 instead
#   warnings.warn(
# about to compute
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# ...

# %%
processor = HNL_Processor_v2_mu.HNL_Processor_v2_mu(isMC=False, applyGenInfo=False)
output_ZMuMu = processor.process(ZMuMu_events, hists_to_process = sensitivity_hists)
# Out:
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 40517 instead
#   warnings.warn(
# about to compute
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# ...

# %%
output_data_fineBinning = Processing_Helpers.processData_v2_mu("root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/2024_Data_mu/", sensitivity_hists, bin_multiplier=10)
# Out:
# root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/2024_Data_mu/Muon0-Run2024B-PromptReco-v1/normalized/Muon0-Run2024B-PromptReco-v1_goodLumi.root
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45387 instead
#   warnings.warn(
# about to compute
# root://cmseos.fnal.gov//store/group/lpclonglived/amalbert/HNL_Tau_Search/2024_Data_mu/Muon0-Run2024C-PromptReco-v1/normalized/Muon0-Run2024C-PromptReco-v1_goodLumi.root
# /uscms/home/amalbert/.local/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35715 instead
#   warnings.warn(
# about to compute
# ...

# %%
importlib.reload(analysis_helpers)
# Out:
# <module 'analysis_helpers' from '/uscms_data/d3/amalbert/el9_work/CMSSW_14_1_0_pre4/src/run3_llp_analyzer/HNL_Plotting_Scripts/../python/HNL_Plotting_HelperFunctions/analysis_helpers.py'>

# %% [markdown]
# ### Plotting with ROOT

# %%
root_dict_data = analysis_helpers.hist_dict_to_fraction_dict(output_data)
root_dict_signal_tau = analysis_helpers.hist_dict_to_fraction_dict(output_tau)
root_dict_signal = analysis_helpers.hist_dict_to_fraction_dict(output)
root_dict_ZMuMu = analysis_helpers.hist_dict_to_fraction_dict(output_ZMuMu)

root_dict_data_fineBinning = analysis_helpers.hist_dict_to_fraction_dict(output_data_fineBinning)
# Out:
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: num_hist (Potential memory leak).
# ...

# %%
analysis_helpers.plot_hists_3_dicts(root_dict_data, root_dict_signal_tau, root_dict_signal, data_label, tau_mu_label, mu_label, logscale=True, fraction=True, outdir='preliminary_root_plots_mu_deltaRBig/')
# Out:
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_deltaRBig//PUPPI MET Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_deltaRBig//Muon p_{T} Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_deltaRBig//Muon #eta Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_deltaRBig//Muon #phi Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_deltaRBig//CSC Rechit Cluster Size Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_deltaRBig//CSC Rechit Cluster Time Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_deltaRBig//CSC Rechit Cluster Time Spread Distribution.png has been created
# ...

# %%
analysis_helpers.plot_hists_one_dicts(root_dict_data_fineBinning, data_label, logscale=True, fraction=True, outdir='preliminary_root_plots_mu_fineBinning_deltaRBig/')
# Out:
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_fineBinning_deltaRBig//PUPPI MET Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_fineBinning_deltaRBig//Muon p_{T} Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_fineBinning_deltaRBig//Muon #eta Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_fineBinning_deltaRBig//Muon #phi Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_fineBinning_deltaRBig//CSC Rechit Cluster Size Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_fineBinning_deltaRBig//CSC Rechit Cluster Time Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_fineBinning_deltaRBig//CSC Rechit Cluster Time Spread Distribution.png has been created
# ...

# %%
analysis_helpers.plot_hists_4_dicts(root_dict_data, root_dict_signal_tau, root_dict_signal, root_dict_ZMuMu, data_label, tau_mu_label, mu_label, ZMuMu_label, logscale=True, fraction=True, outdir='preliminary_root_plots_mu_withZMuMu__deltaRBig/')
# Out:
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_withZMuMu__deltaRBig//PUPPI MET Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_withZMuMu__deltaRBig//Muon p_{T} Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_withZMuMu__deltaRBig//Muon #eta Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_withZMuMu__deltaRBig//Muon #phi Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_withZMuMu__deltaRBig//CSC Rechit Cluster Size Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_withZMuMu__deltaRBig//CSC Rechit Cluster Time Distribution.png has been created
# Info in <TCanvas::Print>: png file preliminary_root_plots_mu_withZMuMu__deltaRBig//CSC Rechit Cluster Time Spread Distribution.png has been created
# ...

# %% [markdown]
# ### Muon Kinematics

# %%
fig, axs = plt.subplots(1,3, figsize=(16,6))
signal_label = "mN=2GeV$_{\\mu}$, cTau=1m"
signal_label_tau = "mN$_{\\tau}$=2GeV, cTau=1m"
data_label = "2024 Data"

#pT
h_pT = output["muon_pt"]
h_pT_tau = output_tau["muon_pt"]
h_pT_data = output_data["muon_pt"]
h_pT.plot(ax=axs[0], label=signal_label, density=True)
h_pT_tau.plot(ax=axs[0], label=signal_label_tau, density=True)
h_pT_data.plot(ax=axs[0], label=data_label, density=True)
axs[0].set_title(h_pT.metadata["title"])
axs[0].set_ylabel(h_pT.metadata["y_label"])
axs[0].legend()
axs[0].set_yscale('log')
axs[0].set_ylim(1e-4, 10)

#eta
h_eta = output["muon_eta"]
h_eta_tau = output_tau["muon_eta"]
h_eta_data = output_data["muon_eta"]
h_eta.plot(ax=axs[1], label=signal_label, density=True)
h_eta_tau.plot(ax=axs[1], label=signal_label_tau, density=True)
h_eta_data.plot(ax=axs[1], label=data_label, density=True)
axs[1].set_title(h_eta.metadata["title"])
axs[1].set_ylabel(h_eta.metadata["y_label"])
axs[1].legend()
axs[1].set_yscale('log')
axs[1].set_ylim(1e-3, 10)

#phi
h_phi = output["muon_phi"]
h_phi_tau = output_tau["muon_phi"]
h_phi_data = output_data["muon_phi"]
h_phi.plot(ax=axs[2], label=signal_label, density=True)
h_phi_tau.plot(ax=axs[2], label=signal_label_tau, density=True)
h_phi_data.plot(ax=axs[2], label=data_label, density=True)
axs[2].set_title(h_phi.metadata["title"])
axs[2].set_ylabel(h_phi.metadata["y_label"])
axs[2].legend()
axs[2].set_yscale('log')
axs[2].set_ylim(1e-3, 10)


plt.show()

# %% [markdown]
# ### CSC Cluster Plots

# %%
fig, axs = plt.subplots(2,2, figsize=(14,10))
signal_label = "mN$_{\\mu}$=2GeV, cTau=1m"
signal_label_tau = "mN$_{\\tau}$=2GeV, cTau=1m"
data_label = "2024 Data"

#eta
h_pT = output["CSC_Cluster_Eta"]
h_pT_tau = output_tau["CSC_Cluster_Eta"]
h_pT_data = output_data["CSC_Cluster_Eta"]
h_pT.plot(ax=axs[0,0], label=signal_label, density=True)
h_pT_tau.plot(ax=axs[0,0], label=signal_label_tau, density=True)
h_pT_data.plot(ax=axs[0,0], label=data_label, density=True)
axs[0,0].set_title(h_pT.metadata["title"])
axs[0,0].set_ylabel(h_pT.metadata["y_label"])
axs[0,0].legend()
axs[0,0].set_yscale('log')
axs[0,0].set_ylim(1e-3, 10)

#size
h_eta = output["CSC_Cluster_Size"]
h_eta_tau = output_tau["CSC_Cluster_Size"]
h_eta_data = output_data["CSC_Cluster_Size"]
h_eta.plot(ax=axs[0,1], label=signal_label, density=True)
h_eta_tau.plot(ax=axs[0,1], label=signal_label_tau, density=True)
h_eta_data.plot(ax=axs[0,1], label=data_label, density=True)
axs[0,1].set_title(h_eta.metadata["title"])
axs[0,1].set_ylabel("Density", fontsize=14)
axs[0,1].set_xlabel("N$_{hits}$", fontsize=14)
axs[0,1].legend()
axs[0,1].set_yscale('log')
axs[0,1].set_ylim(1e-3, 1e-1)
#axs[0,1].grid()

#muon veto pt
h_phi = output["CSC_Cluster_MuonVetoPt"]
h_phi_tau = output_tau["CSC_Cluster_MuonVetoPt"]
h_phi_data = output_data["CSC_Cluster_MuonVetoPt"]
h_phi.plot(ax=axs[1,0], label=signal_label, density=True)
h_phi_tau.plot(ax=axs[1,0], label=signal_label_tau, density=True)
h_phi_data.plot(ax=axs[1,0], label=data_label, density=True)
axs[1,0].set_yscale('log')
axs[1,0].set_title(h_phi.metadata["title"])
axs[1,0].set_ylabel(h_phi.metadata["y_label"])
axs[1,0].legend()
axs[1,0].set_ylim(1e-3, 10)

#jet veto pt
h_phi = output["CSC_Cluster_JetVetoPt"]
h_phi_tau = output_tau["CSC_Cluster_JetVetoPt"]
h_phi_data = output_data["CSC_Cluster_JetVetoPt"]
h_phi.plot(ax=axs[1,1], label=signal_label, density=True)
h_phi_tau.plot(ax=axs[1,1], label=signal_label_tau, density=True)
h_phi_data.plot(ax=axs[1,1], label=data_label, density=True)
axs[1,1].set_yscale('log')
axs[1,1].set_title(h_phi.metadata["title"])
axs[1,1].set_ylabel(h_phi.metadata["y_label"])
axs[1,1].legend()
axs[1,1].set_ylim(1e-3, 10)


plt.show()

# %% [markdown]
# ### MET-Related

# %%
fig, axs = plt.subplots(1,2, figsize=(13,6))
signal_label = "mN$_{\\mu}$=2GeV, cTau=1m"
signal_label_tau = "mN$_{\\tau}$=2GeV, cTau=1m"
data_label = "2024 Data"

#MET
h_pT = output["PUPPI_MET"]
h_pT_tau = output_tau["PUPPI_MET"]
h_pT_data = output_data["PUPPI_MET"]
h_pT.plot(ax=axs[0], label=signal_label, density=True)
h_pT_tau.plot(ax=axs[0], label=signal_label_tau, density=True)
h_pT_data.plot(ax=axs[0], label=data_label, density=True)
axs[0].set_title(h_pT.metadata["title"])
axs[0].set_ylabel(h_pT.metadata["y_label"])
axs[0].legend()
axs[0].set_yscale('log')
axs[0].set_ylim(1e-5, 10)

#dPhi(MET, cluster)
h_eta = output["CSC_Cluster_PuppiMetDPhi"]
h_eta_tau = output_tau["CSC_Cluster_PuppiMetDPhi"]
h_eta_data = output_data["CSC_Cluster_PuppiMetDPhi"]
h_eta.plot(ax=axs[1], label=signal_label, density=True)
h_eta_tau.plot(ax=axs[1], label=signal_label_tau, density=True)
h_eta_data.plot(ax=axs[1], label=data_label, density=True)
axs[1].set_title("d$\phi$(cluster, MET)", fontsize=16)
axs[1].set_ylabel("Density", fontsize=12)
axs[1].set_xlabel("d$\phi$(cluster, MET)", fontsize=12)
axs[1].legend()
axs[1].set_yscale('log')
axs[1].set_ylim(1e-3, 10)


plt.show()

# %%
fig, axs = plt.subplots(1,1, figsize=(6,4))
signal_label = "mN$_{\\mu}$=2GeV, cTau=1m"
signal_label_tau = "mN$_{\\tau}$=2GeV, cTau=1m"
data_label = "2024 Data"

#MET
h_pT = output["CSC_Cluster_DNNScore"]
h_pT_tau = output_tau["CSC_Cluster_DNNScore"]
h_pT_data = output_data["CSC_Cluster_DNNScore"]
h_pT.plot(ax=axs, label=signal_label, density=True)
h_pT_tau.plot(ax=axs, label=signal_label_tau, density=True)
h_pT_data.plot(ax=axs, label=data_label, density=True)

axs.set_title(h_pT.metadata["title"])
axs.set_ylabel("Density")
axs.legend()
#axs.set_yscale('log')
#axs.set_ylim(1e-3, 20)

# %% [markdown]
# ### Topology Variables

# %%
#with updated analyzer branches
fig, axs = plt.subplots(1,2, figsize=(13,6))
signal_label = "mN$_{\\mu}$=2GeV, cTau=1m"
signal_label_tau = "mN$_{\\tau}$=2GeV, cTau=1m"
data_label = "2024 Data"

#dEta
h_pT = output["CSC_Cluster_Muon_DeltaEta"]
h_pT_tau = output_tau["CSC_Cluster_Muon_DeltaEta"]
h_pT_data = output_data["CSC_Cluster_Muon_DeltaEta"]
h_pT.plot(ax=axs[0], label=signal_label, density=True)
h_pT_tau.plot(ax=axs[0], label=signal_label_tau, density=True)
h_pT_data.plot(ax=axs[0], label=data_label, density=True)
axs[0].set_title("$\Delta\eta$(muon, cluster)", fontsize=16)
axs[0].set_ylabel("Density", fontsize=12)
axs[0].set_xlabel("$\Delta\eta$(muon, cluster)", fontsize=12)
axs[0].legend()
axs[0].set_yscale('log')
axs[0].set_ylim(1e-3, 1)

#dPhi
h_eta = output["CSC_Cluster_Muon_DeltaPhi"]
h_eta_tau = output_tau["CSC_Cluster_Muon_DeltaPhi"]
h_eta_data = output_data["CSC_Cluster_Muon_DeltaPhi"]
h_eta.plot(ax=axs[1], label=signal_label, density=True)
h_eta_tau.plot(ax=axs[1], label=signal_label_tau, density=True)
h_eta_data.plot(ax=axs[1], label=data_label, density=True)
axs[1].set_title("$\Delta\phi$(muon, cluster)", fontsize=16)
axs[1].set_ylabel("Density", fontsize=12)
axs[1].set_xlabel("$\Delta\phi$(muon, cluster)", fontsize=12)
axs[1].legend()
axs[1].set_yscale('log')
axs[1].set_ylim(1e-3, 1)


plt.show()
